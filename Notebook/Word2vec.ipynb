# %% [markdown]
# <a href="https://colab.research.google.com/github/YuriArduino/Words_Vectors/blob/main/Notebook/Word2vec.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Vetorização de palavra

# %%
from gensim.models import Word2Vec, KeyedVectors

text= "/content/drive/MyDrive/Word_2_vec_Data/cbow_s300.txt"

modelo = KeyedVectors.load_word2vec_format(text)

# %%
from gensim.models import Word2Vec, KeyedVectors

text= "/content/drive/MyDrive/Word_2_vec_Data/cbow_s300.txt"

modelo = KeyedVectors.load_word2vec_format(text)

# %%
from gensim.models import Word2Vec, KeyedVectors

text= "/content/drive/MyDrive/Word_2_vec_Data/cbow_s300.txt"

modelo = KeyedVectors.load_word2vec_format(text)

# %%
import pandas as pd
import requests
import io


treino_url = 'https://media.githubusercontent.com/media/YuriArduino/Words_Vectors/refs/heads/main/Word_2_vec_Data/treino.csv'
teste_url = 'https://media.githubusercontent.com/media/YuriArduino/Words_Vectors/refs/heads/main/Word_2_vec_Data/teste.csv'

treino_url_content = requests.get(treino_url).content
teste_url_content = requests.get(teste_url).content

treino_df = pd.read_csv(io.StringIO(treino_url_content.decode('utf-8')))
teste_df = pd.read_csv(io.StringIO(teste_url_content.decode('utf-8')))

# %%
treino_df.head(5)
# Out:
#                                                title  \
# 0  Após polêmica, Marine Le Pen diz que abomina n...
# 1  Macron e Le Pen vão ao 2º turno na França, em ...
# 2  Apesar de larga vitória nas legislativas, Macr...
# 3  Governo antecipa balanço, e Alckmin anuncia qu...
# 4  Após queda em maio, a atividade econômica sobe...
#
#                                                 text        date   category  \
# 0  A candidata da direita nacionalista à Presidên...  2017-04-28      mundo
# 1  O centrista independente Emmanuel Macron e a d...  2017-04-23      mundo
# 2  As eleições legislativas deste domingo (19) na...  2017-06-19      mundo
# 3  O número de ocorrências de homicídios dolosos ...  2015-07-24  cotidiano
# 4  A economia cresceu 0,25% no segundo trimestre,...  2017-08-17    mercado
#
#   subcategory                                               link
# 0         NaN  http://www1.folha.uol.com.br/mundo/2017/04/187...
# ...

# %%
teste_df.head(5)
# Out:
#                                                title  \
# 0                                     Grandes irmãos
# 1  Haddad congela orçamento e suspende emendas de...
# 2  Proposta de reforma da Fifa tem a divulgação d...
# 3  Mercado incipiente, internet das coisas conect...
# 4  Mortes: Psicanalista, estudou o autismo em cri...
#
#                                                 text        date   category  \
# 0  RIO DE JANEIRO - O Brasil, cada vez menos famí...  2017-03-06    colunas
# 1  O prefeito de São Paulo, Fernando Haddad (PT),...  2016-08-10    colunas
# 2  A Fifa divulgou, nesta quinta (10), um relatór...  2015-10-09    esporte
# 3  Bueiros, coleiras, aparelhos hospitalares, ele...  2016-11-09    mercado
# 4  Toda vez que o grupo de amigos de Silvana Rabe...  2017-02-07  cotidiano
#
#      subcategory                                               link
# 0      ruycastro  http://www1.folha.uol.com.br/colunas/ruycastro...
# ...

# %%
teste_df.iloc[643].title
# Out:
# 'Somos todos imprevisíveis'

# %%
from sklearn.feature_extraction.text import CountVectorizer


texto =[
        "Tenha um bom dia",
        "Tenha um péssimo dia",
        "Tenha um otimo dia"
        ]

vetorizador = CountVectorizer()
vetorizador.fit(texto)
# Out:
# CountVectorizer()

# %%
print(vetorizador.vocabulary_)
# Out:
# {'tenha': 4, 'um': 5, 'bom': 0, 'dia': 1, 'péssimo': 3, 'otimo': 2}

# %%
vetor_bom = vetorizador.transform(["bom"])
print(vetor_bom.toarray())
# Out:
# [[1 0 0 0 0 0]]

# %%
# !pip install gensim

# %%
from gensim.models import Word2Vec, KeyedVectors

text= "/content/drive/MyDrive/Word_2_vec_Data/cbow_s300.txt"

modelo = KeyedVectors.load_word2vec_format(text)

# %%
modelo.most_similar("freud")
# Out:
# [('jähn', 0.6199313402175903),
#  ('romberg', 0.5987746119499207),
#  ('an-ne-marie', 0.5902712345123291),
#  ('anne-marie', 0.5618393421173096),
#  ('deybel', 0.5361200571060181),
#  ('wilmars', 0.5235167145729065),
#  ('rascher', 0.5043884515762329),
#  ('althusser', 0.45351576805114746),
#  ('cara»,', 0.44022074341773987),
#  ('wallice', 0.4345160722732544)]

# %%
modelo.most_similar(positive=["freud","psicanálise"])
# Out:
# [('criminologia', 0.5499325394630432),
#  ('fenomenologia', 0.5352895259857178),
#  ('romberg', 0.5283076167106628),
#  ('sociologia', 0.526951253414154),
#  ('ontologia', 0.5253108143806458),
#  ('psicologia', 0.5126322507858276),
#  ('antropologia', 0.5105752944946289),
#  ('epistemologia', 0.5080766677856445),
#  ('psiquiatria', 0.5040761232376099),
#  ('cara»,', 0.4918973743915558)]

# %%
modelo.most_similar(positive=["freud","psicanálise"], negative= ["sociologia","fenomenologia"])
# Out:
# [('jähn', 0.37843307852745056),
#  ('anne-marie', 0.3747199475765228),
#  ('peixao', 0.3571247458457947),
#  ('maximorespeito', 0.3562875986099243),
#  ('deusnocontrole', 0.3551945388317108),
#  ('romberg', 0.3471049666404724),
#  ('deusnocomando', 0.3466319143772125),
#  ('ressuscitá', 0.34302273392677307),
#  ('an-ne-marie', 0.3376788794994354),
#  ('todospelademocracia', 0.32821914553642273)]

# %%
# 2. Definir o vetor de 300 dimensões que você deseja converter
# (Substitua pela sua variável de vetor)
meu_vetor = modelo['palavra']

# 3. Converter o vetor na palavra mais próxima
palavras_proximas = modelo.most_similar(positive=[meu_vetor], topn=1)

# 4. Extrair o texto da palavra ideal
palavra_convertida = palavras_proximas[0][0]
print(f"Texto correspondente: {palavra_convertida}")

# %%
import re

# Procura qualquer termo no vocabulário que contenha a raiz "freud"
padrao = re.compile(r'.*freud.*', re.IGNORECASE)
referencias_diretas = [p for p in modelo.index_to_key if padrao.match(p)]

print("Menções diretas encontradas no vocabulário:")
print(referencias_diretas)
# Out:
# Menções diretas encontradas no vocabulário:
# ['freud', 'freudiana', 'freudiano', 'freudenthal', 'freudianos', 'freudianas', 'freude', 'freudenberg', 'freudenstadt', 'schadenfreude', 'freudismo', 'freudianamente', 'freudienne', 'freudianismo', 'freudenthaler', 'freudenberger', 'freudenstein', 'freuds', 'freudo-marxismo', 'freudlose']

# %% [markdown]
# #Vetorização de texto

# %%
treino_df.title.loc[12]
# Out:
# "Daniel Craig será stormtrooper em novo 'Star Wars', diz ator"

# %%
import nltk
import string
# nltk.download('punkt')
# nltk.download('punkt_tab')

def tokenizador(texto):
  texto = texto.lower()
  lista_alfanumerico = []

  nltk.word_tokenize(texto)

  for token_valido in nltk.word_tokenize(texto):
    if token_valido in string.punctuation: continue
    lista_alfanumerico.append(token_valido)

  return lista_alfanumerico

tokenizador("Texto Exemplo, 1234.")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# ['texto', 'exemplo', '1234']

# %%
import numpy as np

def combine_vectors(palavras_numeros):
  """Combina vetores por soma"""

  vetor_resultante = np.zeros(300)

  for pn in palavras_numeros:
    try:
      vetor_resultante += modelo.get_vector(pn)
    except KeyError:
      if pn.isnumeric():
        pn = "0"*len(pn)
        vetor_resultante += modelo.get_vector(pn)
      else:
        vetor_resultante += modelo.get_vector("unknown")


  return vetor_resultante

# %%
palavras_numeros = tokenizador("texto 123")
vetor_texto = combine_vectors(palavras_numeros)
print(len(vetor_texto))
print(vetor_texto)
# Out:
# 300
# [-0.19017101  0.386951   -0.008594    0.30037799  0.159989   -0.101092
#   0.43873099  0.270969   -0.161822    0.018511    0.64161899  0.127828
#  -0.069744   -0.027795    0.124699   -0.119401   -0.28205699 -0.022199
#   0.09366    -0.073118   -0.15385501  0.18351701 -0.16242101  0.03078201
#   0.059678    0.22840899 -0.126967    0.28127    -0.228801   -0.051396
#   0.42185001 -0.10387    -0.014022    0.048888    0.151869    0.1662
#  -0.054594    0.56921098  0.017801    0.357465    0.052317    0.043465
#   0.22348401 -0.084157    0.052653    0.104782    0.169336    0.062566
#  -0.13132     0.221629    0.28166     0.43874899 -0.351202    0.223983
#  -0.253742    0.148257   -0.18561     0.40756399  0.018232   -0.34813
#  -0.15293301  0.206556    0.04577799 -0.35206901  0.309001   -0.012748
#   0.37122799 -0.009942   -0.107348   -0.226903   -0.14168    -0.29536201
#   0.09541     0.22013    -0.159844    0.10897    -0.27485    -0.230404
# ...
